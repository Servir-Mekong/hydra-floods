# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
from osgeo import gdal
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# !gdalinfo '/home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5' | head -20
# Out:
# Driver: HDF5/Hierarchical Data Format Release 5
# Files: /home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5
# Size is 512, 512
# Coordinate System is `'
# Metadata:
#   AdditionalLayers1KM=3
#   AdditionalLayers500M=1
#   AutomaticQualityFlagExplanation=No automatic quality assessment is performed in the PGE
#   CharacteristicBinAngularSize1KM=30
#   CharacteristicBinAngularSize500M=15
#   CharacteristicBinSize1KM=926.625433055556
#   CharacteristicBinSize500M=463.312716527778
#   CoverageCalculationMethod=volume
#   CoverageMinimum=0.00999999977648258
#   DataColumns1KM=1200
#   DataColumns500M=2400
#   DataRows1KM=1200
#   DataRows500M=2400
#   DayNightFlag=Day
#   DeepOceanFlag=Yes

# %%
test1=gdal.Open('/home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5', gdal.GA_ReadOnly)
test1.GetMetadata()
# Out:
# {'AdditionalLayers1KM': '3 ',
#  'AdditionalLayers500M': '1 ',
#  'AutomaticQualityFlagExplanation': 'No automatic quality assessment is performed in the PGE',
#  'CharacteristicBinAngularSize1KM': '30 ',
#  'CharacteristicBinAngularSize500M': '15 ',
#  'CharacteristicBinSize1KM': '926.625433055556 ',
#  'CharacteristicBinSize500M': '463.312716527778 ',
#  'CoverageCalculationMethod': 'volume',
#  'CoverageMinimum': '0.00999999977648258 ',
#  'DataColumns1KM': '1200 ',
#  'DataColumns500M': '2400 ',
#  'DataRows1KM': '1200 ',
#  'DataRows500M': '2400 ',
#  'DayNightFlag': 'Day',
#  'DeepOceanFlag': 'Yes',
#  'EastBoundingCoord': '106.42665 ',
#  'EndTime': '2018-02-22 23:59:00',
#  'FirstLayerSelectionCriteria': 'order of input pointer',
#  'GeoAnyAbnormal': 'False',
#  'GeoEstMaxRMSError': '0 ',
#  'GlobalGridColumns1KM': '43200 ',
#  'GlobalGridColumns500M': '86400 ',
#  'GlobalGridRows1KM': '21600 ',
#  'GlobalGridRows500M': '43200 ',
# ...

# %%
xsize = test1.RasterXSize 
ysize = test1.RasterYSize
print(xsize)
print(ysize)
# Out:
# 512
# 512

# %%
subdata = test1.GetSubDatasets()
subdata
# Out:
# [('HDF5:"/home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5"://HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SensorAzimuth_1',
#   '[1200x1200] //HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SensorAzimuth_1 (16-bit integer)'),
#  ('HDF5:"/home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5"://HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SensorZenith_1',
#   '[1200x1200] //HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SensorZenith_1 (16-bit integer)'),
#  ('HDF5:"/home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5"://HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SolarAzimuth_1',
#   '[1200x1200] //HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SolarAzimuth_1 (16-bit integer)'),
#  ('HDF5:"/home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5"://HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SolarZenith_1',
#   '[1200x1200] //HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SolarZenith_1 (16-bit integer)'),
# ...

# %%
for fname, name in subdata:
    print (name)
    print ("\t"), fname
# Out:
# [1200x1200] //HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SensorAzimuth_1 (16-bit integer)
#
# [1200x1200] //HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SensorZenith_1 (16-bit integer)
#
# [1200x1200] //HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SolarAzimuth_1 (16-bit integer)
#
# [1200x1200] //HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SolarZenith_1 (16-bit integer)
#
# [1200x1200] //HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SurfReflect_M10_1 (16-bit integer)
#
# [1200x1200] //HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SurfReflect_M11_1 (16-bit integer)
#
# [1200x1200] //HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SurfReflect_M1_1 (16-bit integer)
#
# [1200x1200] //HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SurfReflect_M2_1 (16-bit integer)
#
# [1200x1200] //HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SurfReflect_M3_1 (16-bit integer)
#
# [1200x1200] //HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SurfReflect_M4_1 (16-bit integer)
#
# ...

# %%
bands = gdal.Open(test1.GetSubDatasets()[1][0], gdal.GA_ReadOnly)
bands_array = bands.ReadAsArray()
print(bands_array)
# Out:
# [[3445 3452 3458 ... 5698 5696 5691]
#  [3439 3445 3452 ... 5701 5700 5698]
#  [3439 3445 3445 ... 5705 5703 5700]
#  ...
#  [1585 1573 1567 ... 5251 5251 5256]
#  [1585 1579 1573 ... 5247 5251 5256]
#  [1585 1579 1579 ... 5247 5251 5251]]

# %%
bandM1 = gdal.Open('HDF5:"/home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5"://HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SurfReflect_M1_1')
bandM2 = gdal.Open('HDF5:"/home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5"://HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SurfReflect_M2_1')
bandM3 = gdal.Open('HDF5:"/home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5"://HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SurfReflect_M3_1')
bandM4 = gdal.Open('HDF5:"/home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5"://HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SurfReflect_M4_1')
bandM5 = gdal.Open('HDF5:"/home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5"://HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SurfReflect_M5_1')
bandM7 = gdal.Open('HDF5:"/home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5"://HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SurfReflect_M7_1')
bandM8 = gdal.Open('HDF5:"/home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5"://HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SurfReflect_M8_1')
bandM10 = gdal.Open('HDF5:"/home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5"://HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SurfReflect_M10_1')
bandM11 = gdal.Open('HDF5:"/home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5"://HDFEOS/GRIDS/VNP_Grid_1km_2D/Data_Fields/SurfReflect_M11_1')
bandI1 = gdal.Open('HDF5:"/home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5"://HDFEOS/GRIDS/VNP_Grid_500m_2D/Data_Fields/SurfReflect_I1_1')
bandI2 = gdal.Open('HDF5:"/home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5"://HDFEOS/GRIDS/VNP_Grid_500m_2D/Data_Fields/SurfReflect_I2_1')
bandI3 = gdal.Open('HDF5:"/home/ubuntu/hydra/data/VNP09GA_NRT.A2018053.h27v07.001.h5"://HDFEOS/GRIDS/VNP_Grid_500m_2D/Data_Fields/SurfReflect_I3_1')

# %%
#Visible bands in array format
bandM1r = bandM1.ReadAsArray()
bandM2r = bandM2.ReadAsArray()
bandM3r = bandM3.ReadAsArray()
bandM4r = bandM4.ReadAsArray()
bandM5r = bandM5.ReadAsArray()

#Near IR bands in array format
bandM7r = bandM7.ReadAsArray()

#SWIR bands in array format
bandM8r = bandM8.ReadAsArray()
bandM10r = bandM10.ReadAsArray()
bandM11r = bandM11.ReadAsArray()

#Pan bands in array format
bandI1r = bandI1.ReadAsArray()
bandI2r = bandI2.ReadAsArray()
bandI3r = bandI3.ReadAsArray()

# %%
pl.imshow(bandI1r,vmin=0,vmax=1500)

# %%
test1 = None

# %%
# !gdalinfo '/home/ubuntu/hydra/data/SATMS_npp_d20180308_t1255440_e1303436_b32960_c20180308190342349213_nobc_ops.h5'
print('\n')
# !gdalinfo '/home/ubuntu/hydra/data/GATMO_npp_d20180308_t1255440_e1303436_b32960_c20180308190342336760_nobc_ops.h5'
# Out:
# Driver: HDF5/Hierarchical Data Format Release 5
# Files: /home/ubuntu/hydra/data/SATMS_npp_d20180308_t1255440_e1303436_b32960_c20180308190342349213_nobc_ops.h5
# Size is 512, 512
# Coordinate System is `'
# Metadata:
#   Data_Products_ATMS-SDR_Instrument_Short_Name=ATMS
#   Data_Products_ATMS-SDR_N_Collection_Short_Name=ATMS-SDR
#   Data_Products_ATMS-SDR_N_Dataset_Type_Tag=SDR
#   Data_Products_ATMS-SDR_N_Instrument_Flight_SW_Version=23
#   Data_Products_ATMS-SDR_N_Processing_Domain=ops
#   Data_Products_ATMS-SDR_Operational_Mode=NPP Normal Operations, ATMS Operational and Diagnostic
#   Distributor=nob-
#   Mission_Name=S-NPP/JPSS
#   N_Dataset_Source=nob-
#   N_GEO_Ref=GATMO_npp_d20180308_t1255440_e1303436_b32960_c20180308190342336760_nobc_ops.h5
#   N_HDF_Creation_Date=20180308
#   N_HDF_Creation_Time=190342.349213Z
#   Platform_Short_Name=NPP
# Subdatasets:
# ...

# %%
atms=gdal.Open('/home/ubuntu/hydra/data/SATMS_npp_d20180308_t1255440_e1303436_b32960_c20180308190342349213_nobc_ops.h5', gdal.GA_ReadOnly)
subdata2 = atms.GetSubDatasets()
subdata2
# Out:
# [('HDF5:"/home/ubuntu/hydra/data/SATMS_npp_d20180308_t1255440_e1303436_b32960_c20180308190342349213_nobc_ops.h5"://All_Data/ATMS-SDR_All/BrightnessTemperature',
#   '[180x96x22] //All_Data/ATMS-SDR_All/BrightnessTemperature (16-bit unsigned integer)'),
#  ('HDF5:"/home/ubuntu/hydra/data/SATMS_npp_d20180308_t1255440_e1303436_b32960_c20180308190342349213_nobc_ops.h5"://All_Data/ATMS-SDR_All/GainCalibration',
#   '[180x22] //All_Data/ATMS-SDR_All/GainCalibration (32-bit floating-point)'),
#  ('HDF5:"/home/ubuntu/hydra/data/SATMS_npp_d20180308_t1255440_e1303436_b32960_c20180308190342349213_nobc_ops.h5"://All_Data/ATMS-SDR_All/NEdTCold',
#   '[180x22] //All_Data/ATMS-SDR_All/NEdTCold (32-bit floating-point)'),
#  ('HDF5:"/home/ubuntu/hydra/data/SATMS_npp_d20180308_t1255440_e1303436_b32960_c20180308190342349213_nobc_ops.h5"://All_Data/ATMS-SDR_All/NEdTWarm',
#   '[180x22] //All_Data/ATMS-SDR_All/NEdTWarm (32-bit floating-point)'),
# ...

# %%
for fname, name in subdata2:
    print (name)
    print ("\t"), fname
# Out:
# [180x96x22] //All_Data/ATMS-SDR_All/BrightnessTemperature (16-bit unsigned integer)
#
# [180x22] //All_Data/ATMS-SDR_All/GainCalibration (32-bit floating-point)
#
# [180x22] //All_Data/ATMS-SDR_All/NEdTCold (32-bit floating-point)
#
# [180x22] //All_Data/ATMS-SDR_All/NEdTWarm (32-bit floating-point)
#
# [180x22] //All_Data/ATMS-SDR_All/QF20_ATMSSDR (8-bit unsigned character)
#
# [180x22] //All_Data/ATMS-SDR_All/QF21_ATMSSDR (8-bit unsigned character)
#
# [180x22] //All_Data/ATMS-SDR_All/QF22_ATMSSDR (8-bit unsigned character)

# %%
BT = gdal.Open('HDF5:"/home/ubuntu/hydra/data/SATMS_npp_d20180308_t1255440_e1303436_b32960_c20180308190342349213_nobc_ops.h5"://All_Data/ATMS-SDR_All/BrightnessTemperature')
GainCal = gdal.Open('HDF5:"/home/ubuntu/hydra/data/SATMS_npp_d20180308_t1255440_e1303436_b32960_c20180308190342349213_nobc_ops.h5"://All_Data/ATMS-SDR_All/GainCalibration')
NEdTc = gdal.Open('HDF5:"/home/ubuntu/hydra/data/SATMS_npp_d20180308_t1255440_e1303436_b32960_c20180308190342349213_nobc_ops.h5"://All_Data/ATMS-SDR_All/NEdTCold')
NEdTw = gdal.Open('HDF5:"/home/ubuntu/hydra/data/SATMS_npp_d20180308_t1255440_e1303436_b32960_c20180308190342349213_nobc_ops.h5"://All_Data/ATMS-SDR_All/NEdTWarm')
QF20 = gdal.Open('HDF5:"/home/ubuntu/hydra/data/SATMS_npp_d20180308_t1255440_e1303436_b32960_c20180308190342349213_nobc_ops.h5"://All_Data/ATMS-SDR_All/QF20_ATMSSDR')
QF21 = gdal.Open('HDF5:"/home/ubuntu/hydra/data/SATMS_npp_d20180308_t1255440_e1303436_b32960_c20180308190342349213_nobc_ops.h5"://All_Data/ATMS-SDR_All/QF21_ATMSSDR')
QF22 = gdal.Open('HDF5:"/home/ubuntu/hydra/data/SATMS_npp_d20180308_t1255440_e1303436_b32960_c20180308190342349213_nobc_ops.h5"://All_Data/ATMS-SDR_All/QF22_ATMSSDR')
lat = gdal.Open('HDF5:"/home/ubuntu/hydra/data/GATMO_npp_d20180308_t1255440_e1303436_b32960_c20180308190342336760_nobc_ops.h5"://All_Data/ATMS-SDR-GEO_All/Latitude')
lon = gdal.Open('HDF5:"/home/ubuntu/hydra/data/GATMO_npp_d20180308_t1255440_e1303436_b32960_c20180308190342336760_nobc_ops.h5"://All_Data/ATMS-SDR-GEO_All/Longitude')
view = gdal.Open('HDF5:"/home/ubuntu/hydra/data/GATMO_npp_d20180308_t1255440_e1303436_b32960_c20180308190342336760_nobc_ops.h5"://All_Data/ATMS-SDR-GEO_All/SatelliteZenithAngle')

# %%
#BT and other data in array format
BTr = BT.ReadAsArray()
GainCalr = GainCal.ReadAsArray()
NEdTcr = NEdTc.ReadAsArray()
NEdTwr = NEdTw.ReadAsArray()
QF20r = QF20.ReadAsArray()
QF21r = QF21.ReadAsArray()
QF22r = QF22.ReadAsArray()
lats = lat.ReadAsArray()
lons = lon.ReadAsArray()
views = view.ReadAsArray()

# %%
ATMS_sub = gdal.Open(atms.GetSubDatasets()[1][0], gdal.GA_ReadOnly)
ATMS_array = ATMS_sub.ReadAsArray()
print(QF20r.shape)
GainCalr.shape
# Out:
# (180, 22)
# (180, 22)

# %%
imshow(np.flipud(views)>50)

# %%
test = np.zeros_like(BTr).astype(np.uint16)
for i in range(BTr.shape[2]):
    for j in range(BTr.shape[0]):
        test[j,:,i] = (BTr[j,:,i].astype(int) * GainCalr[j,i]) *0.0001

# %%
print(BTr.shape,lats.shape)

import cartopy.crs as ccrs
ax = pl.axes(projection=ccrs.PlateCarree())
plt.pcolormesh(lons, lats, test[:,:,0]>170,transform=ccrs.PlateCarree(),cmap='Blues_r')

ax.coastlines(color='gray')
# Out:
# (180, 96, 22) (180, 96)

# %%
import pandas as pd
df = pd.read_hdf('/home/ubuntu/notebooks/src/hydra/atms_mlc_coeffs.hdf','table')
cols = ['C1','C2','C3','C4','C5','C6','C7','C8','C9','C10','C11','C12','C13','C14','C15','C16','C17','C18','C19','C20','C21','C22',]
df = pd.DataFrame(df,columns = cols)

coeffs = df.to_dict()

keys = list(coeffs.keys())
print(keys)

cal_mlc = np.zeros_like(test)

for c in range(len(keys)):
    chnl = keys[c]
    tbi = coeffs[chnl]['Tbi']
    preds = coeffs[chnl]['predictors']
    popt = coeffs [chnl]['popt']
    for i in range(cal_mlc.shape[0]):
        factor = np.zeros(cal_mlc.shape[1])
        for j in range(popt.size):
            factor = factor + (popt[j]*(test[i,:,preds[j]]-coeffs[keys[j]]['Tbij']))
        cal_mlc[i,:,c] = tbi + factor
# Out:
# ['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10', 'C11', 'C12', 'C13', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21', 'C22']

# %%
imshow(np.flipud(test[:,:,3]))
colorbar()
title('Raw ATMS - Channel 4')
# Out:
# Text(0.5,1,'Raw ATMS - Channel 4')

# %%
imshow(np.flipud(cal_mlc[:,:,3]))
colorbar()
title('Microwave Limb Corrected - Channel 4')
# Out:
# Text(0.5,1,'Microwave Limb Corrected - Channel 4')

# %%
transO = np.mean(test[:,:,3],axis=0)
transT = np.mean(cal_mlc[:,:,3],axis=0)

plot(transO)
plot(transT)

# %%
rain = cal_mlc[:,:,15] - cal_mlc[:,:,0]
ax = pl.axes(projection=ccrs.PlateCarree())
plt.pcolormesh(lons, lats, rain>10,transform=ccrs.PlateCarree(),cmap='Blues_r')

ax.coastlines(color='gray')

# %%
rain = cal_mlc[:,:,15] - cal_mlc[:,:,0]
plt.imshow(np.flipud(rain)<10)

# %%
import pysptools.util as util
import pysptools.eea as eea
import pysptools.abundance_maps as amp

# %%
btDiff = (cal_mlc[:,:,3].astype(np.float)-cal_mlc[:,:,2])
idx = np.where(views<50)
print(idx)
samps = btDiff[idx]
print(btDiff.shape)
samps = samps[:,np.newaxis,np.newaxis]

nfindr = eea.NFINDR()
U = nfindr.extract(samps, 2, maxit=50, normalize=True, ATGP_init=True)
# Out:
# (array([  0,   0,   0, ..., 179, 179, 179]), array([ 9, 10, 11, ..., 83, 84, 85]))
# (180, 96)

# %%
nfindr.display()

# %%
nnls = amp.NNLS()
amaps = nnls.map(btDiff[:,:,np.newaxis], U, normalize=True)
print(U)
# Out:
# [[1.]
#  [0.]]

# %%
ax = pl.axes(projection=ccrs.PlateCarree())
plt.pcolormesh(lons, lats, amaps[:,:,0],transform=ccrs.PlateCarree())

# %%
fWater = np.ma.masked_where(views>50,amaps[:,:,0])
fWater = np.ma.masked_where(rain>10,fWater)

fig, ax = plt.subplots()
ax = pl.axes(projection=ccrs.PlateCarree())
cb = plt.pcolormesh(lons, lats, fWater,transform=ccrs.PlateCarree(),cmap='Blues')
ax.coastlines(color='gray')

cax = fig.add_axes([0.125, 0.05, 0.775, 0.02])
fig.colorbar(cb, cax=cax, orientation='horizontal')
